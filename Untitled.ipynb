# %%
from From_WY.datafetch_163 import WYData

# %%
wy = WYData()

# %%
df  = wy.get_report_type('600779','abc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a954f30ca46c> in <module>()
# ----> 1 df  = wy.get_report_type('600779','abc')
#
# E:\02_DEV\stomirror\From_WY\datafetch_163.py in get_report_type(self, code, rpt_type)
#      36         if not rpt_type_url:
#      37             print(rpt_type_url)
# ---> 38             assert 'Input Report Type NOT FOUND !'
#      39         c = self.fdf.download(rpt_type_url['url'] % code)
#      40         df = pd.read_csv(io.StringIO(c.content.decode('gb18030')))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Out:
#           报告日期 2016-09-30 2016-06-30 2016-03-31 2015-12-31 2015-09-30  \
# 0    总资产利润率(%)       7.62       4.93       4.19        4.9       4.04
# 1   主营业务利润率(%)      63.67       64.5      66.08      60.85         61
# 2   总资产净利润率(%)       7.95          5       4.28       5.15       4.19
# 3   成本费用利润率(%)      34.43      33.78       52.5      15.48      21.49
# 4     营业利润率(%)      24.84      23.98      34.59      12.66      17.39
# 5   主营业务成本率(%)      25.29      25.69      24.98       24.7      26.63
# 6     销售净利率(%)      18.77       18.5      26.08      10.29      11.44
# 7    净资产收益率(%)       10.7       6.82       5.76       6.87       5.55
# 8     股本报酬率(%)      30.52      84.84      16.03      81.32      14.49
# 9    净资产报酬率(%)       10.7      31.03       5.76      31.01       5.55
# 10    资产报酬率(%)       7.62      22.43       4.19      22.14       4.04
# 11    销售毛利率(%)      74.71      74.31      75.02       75.3      73.37
# ...

# %%
df
# Out:
#                    0           1           2           3         4   \
# 报告日期        总资产利润率(%)  主营业务利润率(%)  总资产净利润率(%)  成本费用利润率(%)  营业利润率(%)
# 2016-09-30       7.62       63.67        7.95       34.43     24.84
# 2016-06-30       4.93        64.5           5       33.78     23.98
# 2016-03-31       4.19       66.08        4.28        52.5     34.59
# 2015-12-31        4.9       60.85        5.15       15.48     12.66
# 2015-09-30       4.04          61        4.19       21.49     17.39
# 2015-06-30       3.15       61.71        3.12       24.97     19.71
# 2015-03-31       2.78       63.24        2.87       38.79     27.36
# 2014-12-31      -25.8       54.11      -22.72      -48.55    -84.26
# 2014-09-30      -7.45       54.93        -7.1      -36.92    -60.16
# 2014-06-30      -6.34        50.6       -6.11      -51.13   -105.47
# 2014-03-31      -4.32       52.19       -4.23      -57.27   -140.07
# 2013-12-31      -7.36       53.91       -6.44      -20.66     -31.6
# ...
