# %%
from sqlalchemy import create_engine
import tushare as ts
Engine=create_engine("postgresql://shaw:123456@127.0.0.1:5432/shawdb")

# %%
#行业分类
df_industry_classified = ts.get_industry_classified()
# Out:
# [Getting data:]###################################################

# %%
#概念分类
df_concept_classified = ts.get_concept_classified()
# Out:
# [Getting data:]#################################################################################################################################################################

# %%
#地域分类
df_area = ts.get_area_classified()
# Out:
# C:\Anaconda3\lib\site-packages\tushare\stock\classifying.py:93: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   df = df.sort('area').reset_index(drop=True)

# %%
df_area['classified_type'] = '地域'
df_area.rename(columns={'area': 'c_name'}, inplace=True)

# %%
df_area

# %%
result.to_sql('t_classified', Engine, if_exists='append', index =False )

# %%
import pandas as pd

# %%
result = pd.merge(df_industry_classified, df_concept_classified, how='left', on=['code','name'])

# %%
result = pd.merge(result, df_area, how='left', on=['code','name'])

# %%
result
# Out:
#         code  name c_name_x classified_type_x c_name_y classified_type_y  \
# 0     600039  四川路桥     建筑建材                行业     涉矿概念                概念
# 1     600039  四川路桥     建筑建材                行业     成渝特区                概念
# 2     600039  四川路桥     建筑建材                行业     融资融券                概念
# 3     600039  四川路桥     建筑建材                行业     参股金融                概念
# 4     600068   葛洲坝     建筑建材                行业     水利建设                概念
# 5     600068   葛洲坝     建筑建材                行业     融资融券                概念
# 6     600068   葛洲坝     建筑建材                行业     参股金融                概念
# 7     600068   葛洲坝     建筑建材                行业     整体上市                概念
# 8     600068   葛洲坝     建筑建材                行业   QFII重仓                概念
# 9     600068   葛洲坝     建筑建材                行业     央企50                概念
# 10    600068   葛洲坝     建筑建材                行业     武汉规划                概念
# 11    600068   葛洲坝     建筑建材                行业     金融参股                概念
# 12    600170  上海建工     建筑建材                行业      保障房                概念
# 13    600170  上海建工     建筑建材                行业     装饰园林                概念
# 14    600170  上海建工     建筑建材                行业     融资融券                概念
# 15    600170  上海建工     建筑建材                行业     参股金融                概念
# 16    600170  上海建工     建筑建材                行业     国企改革                概念
# 17    600170  上海建工     建筑建材                行业     上海自贸                概念
# 18    600170  上海建工     建筑建材                行业      迪士尼                概念
# 19    600170  上海建工     建筑建材                行业     上海本地                概念
# 20    600170  上海建工     建筑建材                行业     金融参股                概念
# 21    600248  延长化建     建筑建材                行业     参股金融                概念
# 22    600248  延长化建     建筑建材                行业      陕甘宁                概念
# 23    600284  浦东建设     建筑建材                行业     上海自贸                概念
# 24    600284  浦东建设     建筑建材                行业      迪士尼                概念
# 25    600321  国栋建设     建筑建材                行业     成渝特区                概念
# 26    600321  国栋建设     建筑建材                行业     融资融券                概念
# 27    600326  西藏天路     建筑建材                行业     涉矿概念                概念
# 28    600326  西藏天路     建筑建材                行业     水利建设                概念
# 29    600326  西藏天路     建筑建材                行业     参股金融                概念
# ...      ...   ...      ...               ...      ...               ...
# 9121  002679  福建金森     农林牧渔                行业     风沙治理                概念
# 9122  002696  百洋股份     农林牧渔                行业     本月解禁                概念
# 9123  002696  百洋股份     农林牧渔                行业     业绩预降                概念
# 9124  002696  百洋股份     农林牧渔                行业     水域改革                概念
# 9125  002714  牧原股份     农林牧渔                行业       猪肉                概念
# 9126  002746  仙坛股份     农林牧渔                行业      NaN               NaN
# 9127  300021  大禹节水     农林牧渔                行业     水利建设                概念
# 9128  300021  大禹节水     农林牧渔                行业     参股金融                概念
# 9129  300021  大禹节水     农林牧渔                行业       节能                概念
# 9130  300021  大禹节水     农林牧渔                行业      陕甘宁                概念
# 9131  300021  大禹节水     农林牧渔                行业     风沙治理                概念
# 9132  300021  大禹节水     农林牧渔                行业     土地流转                概念
# 9133  300021  大禹节水     农林牧渔                行业     农村金融                概念
# 9134  300087  荃银高科     农林牧渔                行业     皖江区域                概念
# 9135  300087  荃银高科     农林牧渔                行业     生态农业                概念
# 9136  300087  荃银高科     农林牧渔                行业     生物育种                概念
# 9137  300094  国联水产     农林牧渔                行业     生物育种                概念
# 9138  300094  国联水产     农林牧渔                行业     股权激励                概念
# 9139  300094  国联水产     农林牧渔                行业     水域改革                概念
# 9140  300106  西部牧业     农林牧渔                行业     婴童概念                概念
# 9141  300106  西部牧业     农林牧渔                行业     生态农业                概念
# 9142  300106  西部牧业     农林牧渔                行业     生物育种                概念
# 9143  300143  星河生物     农林牧渔                行业      NaN               NaN
# 9144  300186   大华农     农林牧渔                行业     股权激励                概念
# 9145  300189  神农基因     农林牧渔                行业     生态农业                概念
# 9146  300189  神农基因     农林牧渔                行业     生物育种                概念
# 9147  300268  万福生科     农林牧渔                行业     本月解禁                概念
# 9148  300268  万福生科     农林牧渔                行业      长株潭                概念
# 9149  300313  天山生物     农林牧渔                行业     生物疫苗                概念
# 9150  300381   溢多利     农林牧渔                行业      NaN               NaN
#
#      c_name classified_type
# 0        四川              地域
# 1        四川              地域
# 2        四川              地域
# 3        四川              地域
# 4        湖北              地域
# 5        湖北              地域
# 6        湖北              地域
# 7        湖北              地域
# 8        湖北              地域
# 9        湖北              地域
# 10       湖北              地域
# 11       湖北              地域
# 12       上海              地域
# 13       上海              地域
# 14       上海              地域
# 15       上海              地域
# 16       上海              地域
# 17       上海              地域
# 18       上海              地域
# 19       上海              地域
# 20       上海              地域
# 21       陕西              地域
# 22       陕西              地域
# 23       上海              地域
# 24       上海              地域
# 25       四川              地域
# 26       四川              地域
# 27       西藏              地域
# 28       西藏              地域
# 29       西藏              地域
# ...     ...             ...
# 9121     福建              地域
# 9122     广西              地域
# 9123     广西              地域
# 9124     广西              地域
# 9125     河南              地域
# 9126     山东              地域
# 9127     甘肃              地域
# 9128     甘肃              地域
# 9129     甘肃              地域
# 9130     甘肃              地域
# 9131     甘肃              地域
# 9132     甘肃              地域
# 9133     甘肃              地域
# 9134     安徽              地域
# 9135     安徽              地域
# 9136     安徽              地域
# 9137     广东              地域
# 9138     广东              地域
# 9139     广东              地域
# 9140     新疆              地域
# 9141     新疆              地域
# 9142     新疆              地域
# 9143     广东              地域
# 9144    NaN             NaN
# 9145     海南              地域
# 9146     海南              地域
# 9147     湖南              地域
# 9148     湖南              地域
# 9149     新疆              地域
# 9150     广东              地域
#
# [9151 rows x 8 columns]

# %%
# Out:
#   File "<ipython-input-40-cb9ddec32243>", line 1
#     [df_concept_classified['code']=='600779'
#                                             ^
# SyntaxError: unexpected EOF while parsing
